# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
from scipy.io import wavfile
from collections import defaultdict, Counter
from scipy import signal
import numpy as np
import librosa
import random as rn

from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, TensorDataset
import torchvision
from torchvision import datasets, transforms

# %%
Data = []
Label = []

pad1d = lambda a,i : a[0:i] if a.shape[0] > i else np.hstack((a, np.zeros(i - a.shape[0])))
pad2d = lambda a,i : a[:, 0:i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0], i - a.shape[1]))))

# %%
DATA_DIR = 'C:/Users/ADmin/Desktop/train/audio/'
num = {'zero/' : 0,'one/' : 1,'two/' : 2,'three/' : 3,'four/' : 4,'five/' : 5,'six/' : 6,'seven/' : 7,'eight/' : 8,'nine/' : 9}

for n_folder,n in num.items():
    for fname in os.listdir(DATA_DIR + n_folder):
        wav, _ = librosa.load(DATA_DIR + n_folder + fname)

        Data.append(wav)
        Label.append(n)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(Data, Label, test_size = 0.2,random_state = 123, shuffle = True, stratify = Label)

# %%
train_X = []
train_mfccs = []
train_y = []

#STFT한것, CNN분석하기 위해 Spectrogram으로 만든 것, MF한것, mel-spectorgram한것

for i in range(len(X_train)):
    wav = X_train[i]
    label = y_train[i]

    padded_x = pad1d(wav, 30000)

    mfcc = librosa.feature.mfcc(wav)
    padded_mfcc = pad2d(mfcc,40)

    train_X.append(padded_x)
    train_mfccs.append(padded_mfcc) 
    train_y.append(label)

valid_X = []
valid_mfccs = []
valid_y = []

for i in range(len(X_valid)):
    wav = X_valid[i]
    label = y_valid[i]

    padded_x = pad1d(wav, 30000)

    mfcc = librosa.feature.mfcc(wav)
    padded_mfcc = pad2d(mfcc,40)

    valid_X.append(padded_x)
    valid_mfccs.append(padded_mfcc) 
    valid_y.append(label)

# %%
train_X = torch.cuda.FloatTensor(train_X)
train_mfccs = torch.cuda.FloatTensor(train_mfccs)
train_y = torch.cuda.LongTensor(train_y)

train_mfccs = train_mfccs.unsqueeze(1)

valid_X = torch.cuda.FloatTensor(valid_X)
valid_mfccs = torch.cuda.FloatTensor(valid_mfccs)
valid_y = torch.cuda.LongTensor(valid_y)

valid_mfccs = valid_mfccs.unsqueeze(1)

print('train_X: ', train_X.shape)
print('train_mfccs: ', train_mfccs.shape)
print('train_y: ', train_y.shape)
print('----------------------------------')
print("valid_X: ", valid_X.shape)
print("valid_mfccs: ", valid_mfccs.shape)
print("valid_y: ", valid_y.shape)
# Out:
# train_X:  torch.Size([18932, 30000])
# train_mfccs:  torch.Size([18932, 1, 20, 40])
# train_y:  torch.Size([18932])
# ----------------------------------
# valid_X:  torch.Size([4734, 30000])
# valid_mfccs:  torch.Size([4734, 1, 20, 40])
# valid_y:  torch.Size([4734])

# %%
train_data = TensorDataset(train_mfccs, train_y)
train_data = DataLoader(train_data, batch_size=240, drop_last=False, shuffle=True)

valid_data = TensorDataset(valid_mfccs, valid_y)
valid_data = DataLoader(valid_data, batch_size=60, drop_last=False, shuffle=True)

# %%
len(train_data.dataset)
# Out:
# 18932

# %%
use_cuda = torch.cuda.is_available()

class CNNClassifier(nn.Module):
    
    def __init__(self):
        super(CNNClassifier, self).__init__()
        conv1 = nn.Conv2d(1, 64, 4) # 1@20*40 -> 64@17*37
        pool1 = nn.MaxPool2d(2,2) # 64@8*18
        conv2 = nn.Conv2d(64, 128, 4) # 128@5*15
        pool2 = nn.MaxPool2d(2,2) # 128@2*7
        
        self.conv_module = nn.Sequential(
            conv1,
            nn.ReLU(),
            pool1,
            conv2,
            nn.ReLU(),
            pool2
        )
        
        fc1 = nn.Linear(128*2*7, 64)
        fc2 = nn.Linear(64, 32)
        fc3 = nn.Linear(32, 10)
        
        self.fc_module = nn.Sequential(
            fc1,
            nn.ReLU(),
            fc2,
            nn.ReLU(),
            fc3
        )
        
    def forward(self, x):
        out = self.conv_module(x) # @128*254*7
        dim = 1
        for d in out.size()[1:]:
            dim = dim * d
        out = out.view(-1, dim)
        out = self.fc_module(out)
        return F.softmax(out, dim=1)

# %%
from torchsummary import summary # from torch.autograd import Variable

cnn = CNNClassifier().cuda()
input_size = (1, 20, 40)
summary(cnn, input_size) #mfcc - input size
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 17, 37]           1,088
#               ReLU-2           [-1, 64, 17, 37]               0
#          MaxPool2d-3            [-1, 64, 8, 18]               0
#             Conv2d-4           [-1, 128, 5, 15]         131,200
#               ReLU-5           [-1, 128, 5, 15]               0
#          MaxPool2d-6            [-1, 128, 2, 7]               0
#             Linear-7                   [-1, 64]         114,752
#               ReLU-8                   [-1, 64]               0
#             Linear-9                   [-1, 32]           2,080
#              ReLU-10                   [-1, 32]               0
#            Linear-11                   [-1, 10]             330
# ================================================================
# Total params: 249,450
# Trainable params: 249,450
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.85
# Params size (MB): 0.95
# Estimated Total Size (MB): 1.80
# ----------------------------------------------------------------

# %%
criterion = nn.CrossEntropyLoss()
learning_rate = 0.0005
optimizer = optim.Adam(cnn.parameters(), lr=learning_rate)

num_epochs = 100
num_batches = len(train_data)

train_loss_list = []
valid_loss_list = []
train_accuracy = []
valid_accuracy = []

train_total = 0
train_correct = 0
train_incorrect = 0
valid_total = 0
valid_correct = 0
valid_incorrect = 0

for epoch in range(num_epochs):
    
    train_loss = 0.0
    for i, data in enumerate(train_data):
        x, label = data

        if use_cuda:
            x = x.cuda()
            label = label.cuda()

        optimizer.zero_grad()
        model_output = cnn(x)
        loss = criterion(model_output, label)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()/len(train_data.dataset)
        del loss
        
        for ix in range(len(model_output)):
            if torch.argmax(model_output[ix]).item() == label[ix].item():
                train_correct += 1
            else:
                train_incorrect += 1
        
        if (i+1) % num_batches == 0:
            with torch.no_grad():
                valid_loss = 0.0
                for j, valid in enumerate(valid_data):
                    valid_x, valid_label = valid
                    if use_cuda:
                        valid_x = valid_x.cuda()
                        valid_label = valid_label.cuda()
                    valid_output = cnn(valid_x)
                    v_loss = criterion(valid_output, valid_label)
                    valid_loss += v_loss/len(valid_data.dataset)
                    
                    for idx in range(len(valid_output)):
                        if torch.argmax(valid_output[idx]).item() == valid_label[idx].item():
                            valid_correct += 1
                        else:
                            valid_incorrect += 1                  

            print("epoch: {}/{} | step: {}/{} | trn loss: {:.4f} | val loss: {:.4f}".format(
                epoch+1, num_epochs, i+1, num_batches, train_loss, valid_loss
            ))            
            
            train_loss_list.append(train_loss)
            valid_loss_list.append(valid_loss)
            train_loss = 0.0
    train_accuracy.append((train_correct/(train_correct+train_incorrect))*100)
    valid_accuracy.append((valid_correct/(valid_correct+valid_incorrect))*100)

print('Accuracy of the network on the train audio: %f %%' % (train_accuracy[-1]))
print('Accuracy of the network on the test audio: %f %%' % (valid_accuracy[-1]))
# Out:
# epoch: 1/100 | step: 79/79 | trn loss: 0.0075 | val loss: 0.0290
# epoch: 2/100 | step: 79/79 | trn loss: 0.0071 | val loss: 0.0284
# epoch: 3/100 | step: 79/79 | trn loss: 0.0069 | val loss: 0.0274
# epoch: 4/100 | step: 79/79 | trn loss: 0.0066 | val loss: 0.0266
# epoch: 5/100 | step: 79/79 | trn loss: 0.0066 | val loss: 0.0264
# epoch: 6/100 | step: 79/79 | trn loss: 0.0065 | val loss: 0.0262
# epoch: 7/100 | step: 79/79 | trn loss: 0.0064 | val loss: 0.0262
# epoch: 8/100 | step: 79/79 | trn loss: 0.0064 | val loss: 0.0261
# epoch: 9/100 | step: 79/79 | trn loss: 0.0064 | val loss: 0.0260
# epoch: 10/100 | step: 79/79 | trn loss: 0.0064 | val loss: 0.0259
# epoch: 11/100 | step: 79/79 | trn loss: 0.0063 | val loss: 0.0259
# epoch: 12/100 | step: 79/79 | trn loss: 0.0063 | val loss: 0.0258
# epoch: 13/100 | step: 79/79 | trn loss: 0.0063 | val loss: 0.0260
# epoch: 14/100 | step: 79/79 | trn loss: 0.0063 | val loss: 0.0258
# epoch: 15/100 | step: 79/79 | trn loss: 0.0063 | val loss: 0.0258
# epoch: 16/100 | step: 79/79 | trn loss: 0.0063 | val loss: 0.0258
# epoch: 17/100 | step: 79/79 | trn loss: 0.0063 | val loss: 0.0258
# epoch: 18/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0258
# epoch: 19/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0258
# epoch: 20/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0258
# epoch: 21/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 22/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 23/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 24/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 25/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 26/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 27/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 28/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 29/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 30/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0258
# epoch: 31/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0258
# epoch: 32/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 33/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 34/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 35/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 36/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 37/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 38/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 39/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 40/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 41/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 42/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 43/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 44/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 45/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 46/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 47/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 48/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 49/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 50/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 51/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 52/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 53/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 54/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 55/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 56/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 57/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 58/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 59/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 60/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0255
# epoch: 61/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 62/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 63/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 64/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 65/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 66/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 67/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 68/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 69/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0258
# epoch: 70/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 71/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 72/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 73/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0255
# epoch: 74/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 75/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 76/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0255
# epoch: 77/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0258
# epoch: 78/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 79/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0255
# epoch: 80/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0255
# epoch: 81/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 82/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 83/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 84/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 85/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 86/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 87/100 | step: 79/79 | trn loss: 0.0061 | val loss: 0.0256
# epoch: 88/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 89/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 90/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 91/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 92/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 93/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0257
# epoch: 94/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 95/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0256
# epoch: 96/100 | step: 79/79 | trn loss: 0.0062 | val loss: 0.0255
# epoch: 97/100 | step: 79/79 | trn loss: 0.0061 | val loss: 0.0255
# epoch: 98/100 | step: 79/79 | trn loss: 0.0061 | val loss: 0.0254
# epoch: 99/100 | step: 79/79 | trn loss: 0.0061 | val loss: 0.0255
# epoch: 100/100 | step: 79/79 | trn loss: 0.0061 | val loss: 0.0255
# Accuracy of the network on the train audio: 96.823104 %
# Accuracy of the network on the test audio: 91.732573 %

# %%
plt.rcParams["figure.figsize"] = (10,4)
plt.plot(train_accuracy, label = 'Train Loss')
plt.plot(valid_accuracy, label = 'Validaton Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
